# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#imported datasets
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
#loading dataset
attention = sns.load_dataset('attention')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
type(attention)

# %%
attention.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4a999db7f651> in <module>
# ----> 1 attention.head()
#
# NameError: name 'attention' is not defined

# %%
attention.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a0a728564432> in <module>
# ----> 1 attention.describe()
#
# NameError: name 'attention' is not defined

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.distplot(iris.sepal_length, rug = True, fit = stats.gausshyper);

# %%
#Scatter plot - Biraviate Distribution
sns.jointplot(x = 'sepal_length', y = 'petal_length', data = iris);

# %%
#useful graph when working with large datasets
with sns.axes_style('white'):
    sns.jointplot(x = 'sepal_length',
y = 'petal_length',
data = iris,
kind = 'hex',
color = 'k');

# %%
#Biraviate Distribution
sns.jointplot(x = 'sepal_length',
y = 'petal_length',
data = iris,kind = 'kde');

# %%
sns.pairplot(iris);
